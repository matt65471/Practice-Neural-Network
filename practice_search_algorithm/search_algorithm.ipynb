# %% [markdown]
# The following code/functions below are helpers for the search algorithms developed later.

# %%
from collections import Counter
with open('sgb-words.txt', 'r') as file:
    words = file.read().splitlines()

words_dict = set(words)
letters = [chr(c) for c in range(ord('a'), ord('z') + 1)]

def display(arr):
    return " -> ".join(arr)
# Out:
# {'booby', 'patch', 'afore', 'sumac', 'wasps', 'pends', 'turdy', 'ganef', 'beers', 'vends', 'olden', 'phone', 'poxes', 'shoji', 'guild', 'selah', 'boffo', 'veins', 'mooch', 'finer', 'fetes', 'joyed', 'error', 'goest', 'seeks', 'balms', 'samba', 'toffs', 'waned', 'ogres', 'tyros', 'bison', 'roles', 'yummy', 'latin', 'pause', 'froze', 'riser', 'dowel', 'nicks', 'gapes', 'moper', 'cager', 'junks', 'roach', 'wipes', 'maced', 'moire', 'gloms', 'micks', 'braes', 'expos', 'gravy', 'scads', 'fuzzy', 'twins', 'aurae', 'steal', 'hapax', 'noire', 'taunt', 'trawl', 'cacti', 'limns', 'phase', 'brain', 'absit', 'ditty', 'alive', 'paler', 'piano', 'lungs', 'forts', 'cameo', 'bunts', 'relax', 'filed', 'skate', 'metes', 'weans', 'reeds', 'trues', 'skull', 'lucks', 'yield', 'dicey', 'stunt', 'vireo', 'taped', 'kiosk', 'quoit', 'gouge', 'hemps', 'wrens', 'unmet', 'armor', 'carps', 'coals', 'amuck', 'toyon', 'kales', 'shire', 'giddy', 'vises', 'redip', 'tulle', 'nooky', 'rusks', 'mated', 'clunk', 'bucks', 'craps', 'kited', 'below', 'caner', 'noisy', 'gunks', 'shoat', 'pooch', 'motel', 'redux', 'swags', 'hills', 'wrath', 'vents', 'tonal', 'haunt', 'gyppy', 'lapin', 'shirk', 'unarm', 'sluts', 'chine', 'pairs', 'prank', 'torch', 'heels', 'refly', 'candy', 'dunno', 'riles', 'frock', 'decay', 'belie', 'bluff', 'deter', 'group', 'inert', 'lupus', 'minus', 'spied', 'soaps', 'hinds', 'uncut', 'muons', 'reams', 'lacks', 'gutta', 'beaks', 'girts', 'pinks', 'fatal', 'cubby', 'druid', 'exert', 'sloth', 'flyer', 'wooer', 'inlet', 'bezel', 'guest', 'femur', 'anode', 'roily', 'wired', 'darns', 'chief', 'emcee', 'fusty', 'retch', 'leggo', 'dully', 'fulls', 'reset', 'girds', 'cored', 'aloud', 'maple', 'cords', 'vista', 'thing', 'tares', 'rider', 'sieve', 'panty', 'flash', 'troth', 'soups', 'taxon', 'tired', 'cynic', 'hatch', 'mucho', 'envoy', 'fagot', 'sheik', 'shoed', 'black', 'bathe', 'crack', 'tiger', 'mondo', 'swive', 'mogul', 'stela', 'whirs', 'duffs', 'blurb', 'foamy', 'nodes', 'arias', 'grebe', 'smile', 'lions', 'slays', 'mouth', 'ureas', 'cocks', 'weald', 'gears', 'fudgy', 'indie', 'optic', 'vaned', 'mazer', 'thees', 'bilgy', 'nerts', 'lints', 'dials', 'whack', 'gills', 'gaffe', 'rents', 'downy', 'riced', 'storm', 'rebar', 'pally', 'whens', 'sound', 'aimed', 'burly', 'piety', 'sudsy', 'brush', 'gloat', 'achoo', 'gores', 'wised', 'milks', 'agent', 'yucky', 'ombre', 'baits', 'ferry', 'unzip', 'score', 'cruel', 'exalt', 'haves', 'lemma', 'domes', 'grunt', 'spang', 'antsy', 'croft', 'voxel', 'awoke', 'semen', 'vivas', 'ticks', 'opium', 'cedar', 'gizmo', 'clods', 'diest', 'final', 'pudgy', 'balds', 'rices', 'chant', 'frets', 'round', 'stoae', 'preen', 'undid', 'trice', 'yogis', 'piper', 'shawl', 'spice', 'woody', 'stagy', 'weird', 'chary', 'spans', 'girls', 'sinks', 'hitch', 'unsew', 'baddy', 'bayed', 'latex', 'churl', 'blued', 'zooey', 'ogled', 'hilly', 'tangs', 'puffs', 'mites', 'freer', 'peels', 'dimes', 'eclat', 'kraal', 'canst', 'pokey', 'stony', 'utter', 'suave', 'links', 'idols', 'brash', 'floes', 'pismo', 'mixed', 'acrid', 'snare', 'quirk', 'pings', 'prime', 'teems', 'nerve', 'bench', 'matzo', 'gaily', 'grill', 'modus', 'sours', 'wench', 'light', 'annex', 'rawly', 'brava', 'bipod', 'dashy', 'exits', 'stoic', 'frogs', 'lardy', 'juice', 'quack', 'nerdy', 'wanta', 'ukase', 'girth', 'bares', 'ruble', 'cacao', 'gored', 'ogler', 'expel', 'hexed', 'coset', 'wheel', 'vivre', 'sowed', 'unite', 'elegy', 'necks', 'cured', 'funky', 'crawl', 'highs', 'poach', 'foist', 'loamy', 'wires', 'imbue', 'traps', 'golem', 'miffs', 'chats', 'gooks', 'plait', 'franc', 'gorge', 'bawdy', 'hides', 'loser', 'nabla', 'rusts', 'swami', 'spelt', 'enema', 'drawl', 'pupas', 'slope', 'pawky', 'podia', 'lapse', 'casks', 'helps', 'asana', 'truly', 'eking', 'drays', 'yogic', 'snail', 'mimer', 'docks', 'corer', 'folio', 'suing', 'gluer', 'lance', 'space', 'grabs', 'soaks', 'whose', 'hello', 'friar', 'tuner', 'umbel', 'zincs', 'stalk', 'slash', 'seder', 'snips', 'chain', 'addle', 'deals', 'pu ...

# %% [markdown]
# The heuristic function that I choose was a function that calculated how many letters are different than the target word.

# %%
# Return number of letters away from target word
def heuristic_function(guessed_word: str, target_word: str) -> int:
    if len(guessed_word) != len(target_word):
        raise Exception("Invalid guess, lengths are different")
    n = 0
    for i in range(len(guessed_word)):
        if guessed_word[i] != target_word[i]:
            n += 1
    return n

# %%
from collections import deque
def word_ladder_ucs(start, target, word_list):
    dq = deque()
    dq.append([start])
    seen = set()
    seen.add(start)
    if start == target:
        return [start]
    while dq:
        curr_array = dq.popleft()
        curr_word = curr_array[-1]
        if curr_word == target:
            return curr_array
        for i in range(len(start)):
            curr_word_list = list(curr_word)
            for c in letters:
                if c == curr_word[i]:
                    continue
                temp_copy_word = curr_word_list[:]
                temp_copy_word[i] = c
                next_word = "".join(temp_copy_word)
                if next_word in word_list:
                    if next_word in seen:
                        continue
                    next_array = curr_array[:]
                    next_array.append(next_word)
                    if next_word == target:
                        return next_array
                    else:
                        dq.append(next_array)
                        seen.add(next_word)

    return None
print(word_ladder_ucs("start", "stops", words_dict))
# Out:
# ['start', 'stare', 'store', 'stoae', 'stoas', 'stops']

# %%
import heapq
def word_ladder_astar(start, target, word_list):
    heap = []
    heapq.heappush(heap, (heuristic_function(start, target), [start]))
    if start == target:
        return [start]
    while heap:
        curr_val = heapq.heappop(heap)
        curr_array = curr_val[1]
        curr_word = curr_array[-1]
        if curr_word == target:
            return curr_array
        for i in range(len(start)):
            curr_word_list = list(curr_word)
            for c in letters:
                if c == curr_word[i]:
                    continue
                temp_copy_word = curr_word_list[:]
                temp_copy_word[i] = c
                next_word = "".join(temp_copy_word)
                if next_word in word_list:
                    next_array = curr_array[:]
                    next_array.append(next_word)
                    if next_word == target:
                        return next_array
                    else:
                        heapq.heappush(heap, (heuristic_function(next_word, target) + len(next_array) - 1, next_array))

# %% [markdown]
# Testing code comparing A* and UCS

# %%
def test_astar(start, target):
    print(f"A* running attempting to convert {start} into {target}")
    res = word_ladder_astar(start, target, words_dict)
    if not res:
        print(f"A* failed to convert {start} into {target}")
    else:
        print(f"A* succeeded converting {start} into {target}!")
        print(display(res))

def test_ucs(start, target):
    print(f"UCS running attempting to convert {start} into {target}")
    res = word_ladder_ucs(start, target, words_dict)
    if not res:
        print(f"UCS failed to convert {start} into {target}")
    else:
        print(f"UCS succeeded converting {start} into {target}!")
        print(display(res))

def test(start, target):
    print(f"Testing ({start}, {target})")
    test_astar(start, target)
    test_ucs(start, target)

test("start", "stops")
test("hello", "world")
test("walks", "while")
test("works", "grade")
# Out:
# Testing (start, stops)
# A* running attempting to convert start into stops
# A* succeeded converting start into stops!
# start -> stare -> store -> stoae -> stoas -> stops
# UCS running attempting to convert start into stops
# UCS succeeded converting start into stops!
# start -> stare -> store -> stoae -> stoas -> stops
# Testing (hello, world)
# A* running attempting to convert hello into world
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 25
#      22     test_ucs(start, target)
#      24 test("start", "stops")
# ---> 25 test("hello", "world")
#      26 test("walks", "while")
#      27 test("works", "grade")
#
# Cell In[11], line 21, in test(start, target)
#      19 def test(start, target):
#      20     print(f"Testing ({start}, {target})")
# ---> 21     test_astar(start, target)
#      22     test_ucs(start, target)
#
# Cell In[11], line 3, in test_astar(start, target)
#       1 def test_astar(start, target):
#       2     print(f"A* running attempting to convert {start} into {target}")
# ----> 3     res = word_ladder_astar(start, target, words_dict)
#       4     if not res:
#       5         print(f"A* failed to convert {start} into {target}")
#
# Cell In[10], line 20, in word_ladder_astar(start, target, word_list)
#      18 temp_copy_word = curr_word_list[:]
#      19 temp_copy_word[i] = c
# ---> 20 next_word = "".join(temp_copy_word)
#      21 if next_word in word_list:
#      22     next_array = curr_array[:]
#
# KeyboardInterrupt:
